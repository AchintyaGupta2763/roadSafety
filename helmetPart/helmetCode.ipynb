# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nqaFAdd8RAsMjf9Cp9TX")
project = rf.workspace("learning-evidence").project("helmet-detection_yolov8")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Helmet-Detection_YOLOv8-3 in yolov8:: 100%|██████████| 8350/8350 [00:01<00:00, 5036.45it/s]

# %%
import shutil
import os

# Define the source and destination folder paths
source_folder = '/content/Helmet-Detection_YOLOv8-3'  # Change this to your source folder
destination_folder = '/content/drive/MyDrive/trialsHelmetSRM/helmetPart'  # Change this to your destination folder

# Ensure the destination folder exists, if not, create it
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Move the folder
try:
    shutil.move(source_folder, destination_folder)
    print(f'Folder "{source_folder}" has been moved to "{destination_folder}"')
except Exception as e:
    print(f"Error: {e}")
# Out:
# Folder "/content/Helmet-Detection_YOLOv8-3" has been moved to "/content/drive/MyDrive/trialsHelmetSRM/helmetPart"

# %%
# %cd /content/drive/MyDrive/trialsHelmetSRM/helmetPart
# Out:
# /content/drive/MyDrive/trialsHelmetSRM/helmetPart

# %%
# !pip install ultralytics==8.2.60
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.9/802.9 kB 47.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# Ultralytics YOLOv8.2.60 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.5/112.6 GB disk)

# %%
from ultralytics import YOLO, settings
dataset_path = '/content/Helmet-Detection_YOLOv8-3'
settings.update({'datasets_dir': dataset_path})
dataset_yaml = f'{dataset_path}/data.yaml'
model = YOLO('yolov8n.pt')
model.train(data=dataset_yaml, epochs=100, imgsz=640, device='0', batch=16)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 162MB/s]
# New https://pypi.org/project/ultralytics/8.3.15 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.60 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import shutil

# Replace 'folder_path' with the actual path to your folder
folder_path = '/content/drive/MyDrive/trialsHelmetSRM/helmetPart'
output_filename = '/content/helmetPart.zip'

# Zip the folder
shutil.make_archive(output_filename.replace('.zip', ''), 'zip', folder_path)
from google.colab import files

# Download the zip file
files.download(output_filename)
